# %% [markdown]
# <a href="https://colab.research.google.com/github/drmartins2/EDIT_DE/blob/main/5.%20Data%20Streaming/examples/example_3_api_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()
sc = spark.sparkContext

# %%
# !rm -rf /content/landing
# !rm -rf /content/bronze
# !mkdir -p /content/landing

# %% [markdown]
# ## Simulate producer:
# - extract data from API
# - store data as json in the lake
# - run task async

# %%
import requests
from pyspark.sql.types import *
import json
import datetime
import asyncio


# Check async function? - This will just read the data from the assigned API and save it as JSON in the landing folder
async def ingest_from_api(url: str, table: str, schema: StructType = None):
  response = requests.get(url)
  timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
  if response.status_code == 200:
    data = response.json()
    with open(f"/content/landing/{table}_{int(timestamp)}.json", "w") as f:
        json.dump(data, f)

#  This will execute the API ingest method for the assigned loop times with th provided interval_time
async def producer(loop: int, interval_time: int):
  for i in range(loop):
    await ingest_from_api("https://api.carrismetropolitana.pt/vehicles", "vehicles")
    await ingest_from_api("https://api.carrismetropolitana.pt/lines", "lines")
    await asyncio.sleep(interval_time)

# Executes the producer method for 10 times with an interval of 30 sec (Check asyncio?)
async def main():
  asyncio.create_task(producer(10, 30))

await main()

# %% [markdown]
# - Read from /content/landing as streaming
# - store data in memory (for testing)
# - store data in the bronze layer

# %%
from pyspark.sql.types import *

vehicle_schema = StructType([StructField('bearing', IntegerType(), True),
                             StructField('block_id', StringType(), True),
                             StructField('current_status', StringType(), True),
                             StructField('id', StringType(), True),
                             StructField('lat', FloatType(), True),
                             StructField('line_id', StringType(), True),
                             StructField('lon', FloatType(), True),
                             StructField('pattern_id', StringType(), True),
                             StructField('route_id', StringType(), True),
                             StructField('schedule_relationship', StringType(), True),
                             StructField('shift_id', StringType(), True),
                             StructField('speed', FloatType(), True),
                             StructField('stop_id', StringType(), True),
                             StructField('timestamp', TimestampType(), True),
                             StructField('trip_id', StringType(), True)])

stream = spark.readStream.format("json").schema(vehicle_schema).load("/content/landing/vehicles*")

dedup = stream.dropDuplicates()

# %%
# Validates if dedup method is a streaming process and if it's running
dedup.isStreaming
# Out:
# True

# %%
# using memory for testing, needs this to run this cell as many times as we want
# once Spark streaming doens't allow to name a query with the same name in the same session
try:
  if query.isActive:
    query.stop()
except:
  pass

# format("memory") writes directly to memory instead of a physical target - only used for testing purposes
# this will create a querable table "vehicles"
query = (dedup.writeStream.format("memory").option("queryName", "vehicles").start())

# %%
# AUX functions for streaming troubleshooting

# Gives us the current status of the query method defined above every time we run this
query.status

# Useful for troubleshooting, gives us the metadata fo the micro batch running
query.lastProgress

# If we want to see the metadata info from all the micro batches executions
query.recentProgress
# Out:
# [{'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:58:28.200Z',
#   'batchId': 0,
#   'numInputRows': 3999,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 338.3821289558301,
#   'durationMs': {'addBatch': 11594,
#    'commitOffsets': 74,
#    'getBatch': 23,
#    'latestOffset': 61,
#    'queryPlanning': 22,
#    'triggerExecution': 11818,
#    'walCommit': 41},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 3594,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': None,
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 3999,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 338.3821289558301}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 3594}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:58:50.028Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:59:00.034Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:59:10.041Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:59:20.043Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:59:30.043Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:59:40.046Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T09:59:50.053Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:00:00.056Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:00:10.057Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:00:20.065Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:00:30.073Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:00:40.076Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:00:50.080Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:01:00.083Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:01:10.081Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:01:20.089Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:01:30.090Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:01:40.095Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:01:50.104Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:02:00.112Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:02:10.123Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 8, 'triggerExecution': 8},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:02:20.133Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:02:30.144Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 10, 'triggerExecution': 10},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:02:40.161Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:02:50.166Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:03:00.175Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:03:10.187Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:03:20.190Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:03:30.193Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:03:40.194Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:03:50.201Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:04:00.205Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:04:10.217Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:04:20.217Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:04:30.228Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:04:40.232Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:04:50.236Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:05:00.246Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:05:10.257Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:05:20.260Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
# ...
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:07:50.369Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:08:00.378Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:08:10.381Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:08:20.388Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:08:30.389Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:08:40.399Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:08:50.406Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:09:00.416Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:09:10.418Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:09:20.428Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:09:30.429Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:09:40.437Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': '3cc67683-8494-4644-9fa9-fee399ff797e',
#   'runId': '17f9249b-09b2-4214-af99-b677a223495c',
#   'name': 'vehicles',
#   'timestamp': '2024-11-30T10:09:50.440Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [{'operatorName': 'dedupe',
#     'numRowsTotal': 3594,
#     'numRowsUpdated': 0,
#     'allUpdatesTimeMs': 3137,
#     'numRowsRemoved': 0,
#     'allRemovalsTimeMs': 0,
#     'commitTimeMs': 4975,
#     'memoryUsedBytes': 1573832,
#     'numRowsDroppedByWatermark': 0,
#     'numShufflePartitions': 200,
#     'numStateStoreInstances': 200,
#     'customMetrics': {'loadedMapCacheHitCount': 0,
#      'loadedMapCacheMissCount': 0,
#      'numDroppedDuplicateRows': 405,
#      'stateOnCurrentVersionSizeBytes': 1545032}}],
#   'sources': [{'description': 'FileStreamSource[file:/content/landing/vehicles*]',
#     'startOffset': {'logOffset': 0},
#     'endOffset': {'logOffset': 0},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}}]

# %%
spark.sql("select * from vehicles").show()
# Out:
# +-------+--------------------+--------------+--------+---------+-------+---------+----------+--------+---------------------+------------+---------+-------+-------------------+--------------------+
# |bearing|            block_id|current_status|      id|      lat|line_id|      lon|pattern_id|route_id|schedule_relationship|    shift_id|    speed|stop_id|          timestamp|             trip_id|
# +-------+--------------------+--------------+--------+---------+-------+---------+----------+--------+---------------------+------------+---------+-------+-------------------+--------------------+
# |    183|                1155| IN_TRANSIT_TO| 42|1155|38.917503|   2626|-9.322189|  2626_0_1|  2626_0|            SCHEDULED|       44537|11.666667| 080448|2024-11-30 09:53:02|2626_0_1|160|1|09...|
# |     87|20241130-64020162...| IN_TRANSIT_TO|44|12744|38.525368|   4730| -8.88922|  4730_2_1|  4730_2|            SCHEDULED|113060000007|      0.0| 160141|2024-11-30 09:53:43|4730_2_1|3000|083...|
# |    293|           2_2032-21|    STOPPED_AT| 41|1352|38.757717|   1707|-9.222284|  1707_0_1|  1707_0|            SCHEDULED|        2032|3.3333333| 030613|2024-11-30 09:53:31|1707_0_1_0930_095...|
# |    110|           2_2040-21|   INCOMING_AT| 41|1707|38.764614|   1012|-9.216347|  1012_0_3|  1012_0|            SCHEDULED|        2040|5.8333335| 030356|2024-11-30 09:52:36|1012_0_3_0930_095...|
# |     24|      ESC_SAB_ES3020| IN_TRANSIT_TO|   43|13|38.432724|   3204|-9.183736|  3204_0_1|  3204_0|            SCHEDULED|      ES3020| 9.722222| 150209|2024-11-30 09:52:09|3204_0_1_0930_095...|
# |     85|           2_2310-21|    STOPPED_AT| 41|1219|38.713337|   1638|-9.362506|  1638_3_2|  1638_3|            SCHEDULED|        2310|      2.5| 050440|2024-11-30 09:51:57|1638_3_2_0930_095...|
# |    288|           2_2603-21| IN_TRANSIT_TO| 41|1295|38.761444|   1518|-9.234202|  1518_0_2|  1518_0|            SCHEDULED|        2630| 9.722222| 030097|2024-11-30 09:54:02|1518_0_2_0930_095...|
# +-------+--------------------+--------------+--------+---------+-------+---------+----------+--------+---------------------+------------+---------+-------+-------------------+--------------------+
# only showing top 20 rows

# %%
# It will just stop the query execution, but the data will remain available in memory until the spark session is running
query.stop()

# %%
spark.sql("select * from vehicles").show()
# Out:
# +-------+--------------------+--------------+--------+---------+-------+---------+----------+--------+---------------------+------------+---------+-------+-------------------+--------------------+
# |bearing|            block_id|current_status|      id|      lat|line_id|      lon|pattern_id|route_id|schedule_relationship|    shift_id|    speed|stop_id|          timestamp|             trip_id|
# +-------+--------------------+--------------+--------+---------+-------+---------+----------+--------+---------------------+------------+---------+-------+-------------------+--------------------+
# |    183|                1155| IN_TRANSIT_TO| 42|1155|38.917503|   2626|-9.322189|  2626_0_1|  2626_0|            SCHEDULED|       44537|11.666667| 080448|2024-11-30 09:53:02|2626_0_1|160|1|09...|
# |      0|      ESC_SAB_ES1049|    STOPPED_AT| 43|2378| 38.63942|   3103|-9.149403|  3103_0_2|  3103_0|            SCHEDULED|      ES1049|      0.0| 140137|2024-11-30 09:52:39|3103_0_2_0900_092...|
# |    296|             4002-21|   INCOMING_AT|  42|293|38.810513|   2730|-9.099896|  2730_0_2|  2730_0|            SCHEDULED|        4002|      0.0| 071249|2024-11-30 09:52:09|2730_0_2|2|1|0930...|
# |     40|           2_2737-21| IN_TRANSIT_TO| 41|1727|38.785305|   1253|-9.466183|  1253_0_3|  1253_0|            SCHEDULED|        2737| 8.333333| 171940|2024-11-30 09:52:15|1253_0_3_0900_092...|
# |     24|      ESC_SAB_ES3020| IN_TRANSIT_TO|   43|13|38.432724|   3204|-9.183736|  3204_0_1|  3204_0|            SCHEDULED|      ES3020| 9.722222| 150209|2024-11-30 09:52:09|3204_0_1_0930_095...|
# |     85|           2_2310-21|    STOPPED_AT| 41|1219|38.713337|   1638|-9.362506|  1638_3_2|  1638_3|            SCHEDULED|        2310|      2.5| 050440|2024-11-30 09:51:57|1638_3_2_0930_095...|
# |    288|           2_2603-21| IN_TRANSIT_TO| 41|1295|38.761444|   1518|-9.234202|  1518_0_2|  1518_0|            SCHEDULED|        2630| 9.722222| 030097|2024-11-30 09:54:02|1518_0_2_0930_095...|
# +-------+--------------------+--------------+--------+---------+-------+---------+----------+--------+---------------------+------------+---------+-------+-------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Simulating from landing zone (memory) to Bronze layer (store transformed parquet file)

# %%
# !rm -rf /content/bronze

# %%
from pyspark.sql.functions import *

# watermark is necessary because of the aggregation
transformed = stream.withWatermark("timestamp", "60 seconds")
agg = (transformed
       .groupBy(window(transformed.timestamp, "5 minutes"), col("current_status"))
       .agg(min(transformed.timestamp).alias("init_timestamp"), count("*").alias("count")))

def insert_vehicles(df, batch_id):
  #df2 = df.groupBy("window").pivot("current_status").sum("count")
  df.write.format("parquet").mode("append").save("/content/bronze/vehicles")

# using memory for testing
query2 = (agg
          .writeStream
          .outputMode("append")
          # to write into a parquet or json file using spark streaming, it required to use a foreach method
          .foreachBatch(insert_vehicles)
          # In this case only ingesting from one entity, so only one checkpoint folder is required
          .option("checkpointLocation", "/content/bronze/checkpoint")
          .trigger(processingTime='20 seconds')
          .start())

# %%
spark.read.format("parquet").load("/content/bronze/vehicles/*").show(100, False)
# Out:
# +------------------------------------------+--------------+-------------------+-----+
# |window                                    |current_status|init_timestamp     |count|
# +------------------------------------------+--------------+-------------------+-----+
# |{2024-11-30 09:50:00, 2024-11-30 09:55:00}|IN_TRANSIT_TO |2024-11-30 09:51:37|1187 |
# |{2024-11-30 09:50:00, 2024-11-30 09:55:00}|INCOMING_AT   |2024-11-30 09:51:34|411  |
# |{2024-11-30 09:50:00, 2024-11-30 09:55:00}|STOPPED_AT    |2024-11-30 09:51:26|583  |
# +------------------------------------------+--------------+-------------------+-----+

# %% [markdown]
# ## Report
# - show vehicles by status in 5-min window time
# - one line per window time

# %%
def pivot_data(df: DataFrame):
  result = df.orderBy("init_timestamp").groupBy("window").pivot("current_status").sum("count")
  result.show(100, False)

df = spark.read.format("parquet").load("/content/bronze/vehicles/*")
pivot_data(df)
# Out:
# +------------------------------------------+-----------+-------------+----------+
# |window                                    |INCOMING_AT|IN_TRANSIT_TO|STOPPED_AT|
# +------------------------------------------+-----------+-------------+----------+
# |{2024-11-30 09:50:00, 2024-11-30 09:55:00}|411        |1187         |583       |
# +------------------------------------------+-----------+-------------+----------+

# %%
query2.stop()
